# %% [markdown]
# # 4 - Spark-Coding-Environment

# %%
# !pip3 install pyspark

# %%
from pyspark import SparkContext, SparkConf

# %%
# Initializing Spark
conf = SparkConf().setAppName('testApp1').setMaster('local[*]')
sc = SparkContext(conf=conf)

# solo se puede tener un sc.
# el asterisco indica utilizar todos los cores posibles

# %%
print(sc)
# Out:
# <SparkContext master=local[*] appName=testApp1>

# %%
sc.defaultParallelism  # cantidad de cores
# Out:
# 2
